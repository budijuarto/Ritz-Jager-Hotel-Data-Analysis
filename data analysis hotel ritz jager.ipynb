# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.graph_objects as gro

# %%
df = pd.read_csv('Ritz_Jager_Data.csv')

# %% [markdown]
# #Preprocessing data

# %%
df.head()
# Out:
#      hotel_type  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.isnull().sum()
# Out:
# hotel_type                             0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal_type                              0
# country_origin                       488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df[["agent","company",'children']].hist(figsize=(10,8),bins=5,color='B')
plt.tight_layout(pad = 2)
plt.show()

# %% [markdown]
# # hitung presentase dari data null

# %%
df.isnull().sum() / len(df) *100
# Out:
# hotel_type                         0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal_type                          0.000000
# country_origin                     0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %% [markdown]
# from data above we can see that there are null data in column children, country_origin, agent, and company. We will fill children and country origin using mode. Agent and company using mean

# %%
agentClean=df['agent'].mean()
companyClean=df['company'].mean()
df['agent']=df['agent'].fillna(agentClean)
df['company']=df['company'].fillna(companyClean)
df.head()
# Out:
#      hotel_type  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
childrenClean=df['children'].mode()[0]#You must add [0] that indicate you fill with the first value in index of mode
df['children']=df['children'].fillna(childrenClean)
df.head()
# Out:
#      hotel_type  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
cleanCountry=df['country_origin'].mode()[0] #You must add [0] that indicate you fill with the first value in index of mode
df['country_origin']=df['country_origin'].fillna(cleanCountry)

# %%
df.isnull().sum()
# Out:
# hotel_type                        0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal_type                         0
# country_origin                    0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# Clean country code data into country name to easier interpretation

# %%
import pycountry

#list the name country
list_alpha_2 = [i.alpha_2 for i in list(pycountry.countries)]
list_alpha_3 = [i.alpha_3 for i in list(pycountry.countries)]    

def country_flag(df):
    if (len(df['countrycode'])==2 and df['countrycode'] in list_alpha_2):
        return pycountry.countries.get(alpha_2=df['countrycode']).name
    elif (len(df['countrycode'])==3 and df['countrycode'] in list_alpha_3):
        return pycountry.countries.get(alpha_3=df['countrycode']).name
    else:
        return 'Invalid Code'

# %% [markdown]
# # 1. Where do the guests come from?

# %% [markdown]
# guest who come to hotel is the guest who don't cancel their booking hotel

# %%
comingGuest = df[df['is_canceled']==0]
countryGuest = comingGuest.country_origin.value_counts()
countryGuest=pd.DataFrame(countryGuest)
countryGuest.head()
# Out:
#      country_origin
# PRT           21492
# GBR            9676
# FRA            8481
# ESP            6391
# DEU            6069

# %%
#change country

#reset the index first
countryGuest= pd.DataFrame(countryGuest).reset_index()
countryGuest.rename(columns={"index": "countrycode", "country_origin":"guest"}, inplace=True)

# %%
countryGuest['countrycode']=countryGuest.apply(country_flag, axis = 1)
countryGuest
# Out:
#                      countrycode  guest
# 0                       Portugal  21492
# 1                 United Kingdom   9676
# 2                         France   8481
# 3                          Spain   6391
# 4                        Germany   6069
# 5                        Ireland   2543
# 6                          Italy   2433
# 7                        Belgium   1868
# 8                    Netherlands   1717
# 9                  United States   1596
# 10                        Brazil   1394
# 11                   Switzerland   1302
# 12                       Austria   1033
# 13                         China   1025
# 14                        Sweden    797
# 15                        Poland    704
# 16                         China    537
# 17                        Israel    500
# 18                        Norway    426
# 19            Russian Federation    393
# 20                       Finland    378
# 21                       Romania    366
# ...

# %% [markdown]
# Portugal is the most visited Country

# %%
sns.countplot(df['country_origin'], order = df['country_origin'].value_counts().iloc[0:3].index, color='b')

# %% [markdown]
# # 2. How much do guests pay for a room per night?

# %%
df['adr'].describe()
# Out:
# count    119390.000000
# mean        101.831122
# std          50.535790
# min          -6.380000
# 25%          69.290000
# 50%          94.575000
# 75%         126.000000
# max        5400.000000
# Name: adr, dtype: float64

# %%
fig,ax = plt.subplots()
fig.set_size_inches(16, 8)

ax = sns.distplot(df.adr).set(title='Hotel Price Distribution')

# %% [markdown]
# as seen from above chart that there is outlier which minus price from hotel so we can ignore that. we can find the price of hotel per night by using the mean. But before that we must apply filter of type of hotel, price, cancellation,and adult and children must be at least one

# %%
city_hotel = df[(df['hotel_type']=='City Hotel') & (df['is_canceled'] == 0) & (df.adr > 0) & (df.adults>0) & (df.children>0)]
resort_hotel = df[(df['hotel_type']=='Resort Hotel') & (df['is_canceled'] == 0) & (df.adr > 0) & (df.adults>0) & (df.children>0)]

print('For non-canceled reservation and all room types:\nCity Hotel mean price: ${}\nResort Hotel mean price: ${}'.format(city_hotel.adr.median(),resort_hotel.adr.median()))
# Out:
# For non-canceled reservation and all room types:
# City Hotel mean price: $149.0
# Resort Hotel mean price: $155.0

# %% [markdown]
# # 3. How does the price per night vary over the year?(assumption the price at that month or at the day of arrival)

# %%
price_year = df.groupby('arrival_date_year')['adr'].mean().reset_index()

# %%
price_year
# Out:
#    arrival_date_year         adr
# 0               2015   87.178515
# 1               2016   98.325863
# 2               2017  114.637950

# %%
df['reservation_status_date'].dtypes
# Out:
# dtype('O')

# %%
df['reservation_status_date']
# Out:
# 0        2015-01-07
# 1        2015-01-07
# 2        2015-02-07
# 3        2015-02-07
# 4        2015-03-07
# 5        2015-03-07
# 6        2015-03-07
# 7        2015-03-07
# 8        2015-06-05
# 9        2015-04-22
# 10       2015-06-23
# 11       2015-05-07
# 12       2015-05-07
# 13       2015-05-07
# 14       2015-05-07
# 15       2015-05-07
# 16       2015-05-07
# 17       2015-02-07
# 18       2015-02-07
# 19       2015-05-07
# 20       2015-06-07
# 21       2015-07-07
# 22       2015-07-07
# 23       2015-07-07
# 24       2015-01-07
# 25       2015-08-07
# 26       2015-08-07
# 27       2015-11-05
# 28       2015-08-07
# 29       2015-08-07
#             ...
# 119360   2017-04-09
# 119361   2017-04-09
# 119362   2017-04-09
# 119363   2017-04-09
# 119364   2017-04-09
# 119365   2017-04-09
# 119366   2017-04-09
# 119367   2017-04-09
# 119368   2017-04-09
# 119369   2017-04-09
# 119370   2017-04-09
# 119371   2017-04-09
# 119372   2017-04-09
# 119373   2017-04-09
# ...

# %%
# changes reservation date into dates
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.dtypes
# Out:
# hotel_type                                object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal_type                                 object
# country_origin                            object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
#split year and month
monthPrice = df[['adr','reservation_status_date']]
avg=monthPrice.groupby([(monthPrice['reservation_status_date'].dt.year),(monthPrice['reservation_status_date'].dt.month)]).mean()
avg
# Out:
#                                                         adr
# reservation_status_date reservation_status_date
# 2014                    10                        62.800000
#                         11                         0.000000
# 2015                    1                         69.320728
#                         2                         74.629186
#                         3                         93.561667
#                         4                         91.010746
#                         5                         88.208858
#                         6                         86.040228
#                         7                         95.892337
#                         8                        106.164198
#                         9                         98.050467
#                         10                        75.446716
#                         11                        71.937994
#                         12                        77.003767
# ...

# %%
avgmonth=avg['adr'].pct_change()
plt.figure(figsize=(15,5))
plt.title('the price per night vary over the year')
plt.xlabel('Month and Year')
plt.ylabel('Percentage Change')
avgmonth.plot()

# %%
no_cancel = df[df['is_canceled']==0]
pd.pivot_table(no_cancel, index=['reservation_status_date'], values='adr',aggfunc={'adr':np.mean}).plot(kind='line',color='r')
plt.title("The Price per Night Vary Over the Year by date")
plt.xlabel("Date")
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
pd.pivot_table(no_cancel, index=['reservation_status_date'], values='adr',aggfunc={'adr':np.mean})
# Out:
#                                 adr
# reservation_status_date
# 2015-01-07                31.650000
# 2015-01-08               138.444565
# 2015-01-09               110.008657
# 2015-01-10                86.723818
# 2015-01-11                59.431300
# 2015-01-12                49.028519
# 2015-02-07                88.231429
# 2015-02-08               148.622941
# 2015-02-09               106.009756
# 2015-02-10                85.564762
# 2015-02-11                67.906842
# 2015-02-12                49.385806
# 2015-03-07                97.645205
# 2015-03-08               116.742391
# 2015-03-09                96.981136
# 2015-03-10                87.477500
# 2015-03-11                70.348077
# 2015-03-12                51.733333
# 2015-04-07               110.480000
# 2015-04-08               107.328750
# 2015-04-09               116.950685
# 2015-04-10                97.616943
# 2015-04-11                61.634048
# 2015-04-12                48.747013
# ...

# %% [markdown]
# # 4. Which are the busiest months?

# %%
busyMonth = df['arrival_date_month'].value_counts()
busyMonth
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %%
#visualization
sns.set(rc={'figure.figsize':(25,10)})
sns.countplot(df['arrival_date_month'], order=['January','February','March','April','May',
'June','July','August','September','October','November','December'], color='g')
plt.title('Busies Month')
plt.xlabel('Month')
plt.ylabel('Number of Visitor')
# Out:
# Text(0, 0.5, 'Number of Visitor')

# %% [markdown]
# August is busiest month because July and August is Summer Holiday ar

# %% [markdown]
# # 5. How long do people stay at the hotels?

# %%
print('The average guest spends nights at weekday is {}'.format(round(df['stays_in_week_nights'].mean())))
print('The average guest spends nights at weekend is {}'.format(round(df['stays_in_weekend_nights'].mean())))
# Out:
# The average guest spends nights at weekday is 3
# The average guest spends nights at weekend is 1

# %% [markdown]
# # 6. Bookings by market segment

# %%
sns.countplot(df['market_segment'], order = df['market_segment'].value_counts().index, color='b')

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %% [markdown]
# # 7. How many bookings were cancelled?

# %%
cancel = df[df['is_canceled']==1]
print('There are {} bookings that have been cancelled'.format(len(cancel)))
print('So the cancelation precentation is {}%'.format(round(len(cancel)/len(df['is_canceled'])*100)))
# Out:
# There are 44224 bookings that have been cancelled
# So the cancelation precentation is 37%

# %% [markdown]
# # **Which month has the highest number of cancellations?**

# %%
df[df.is_canceled == 1].groupby('arrival_date_month').size().sort_values(ascending=False)
# Out:
# arrival_date_month
# August       5239
# July         4742
# May          4677
# June         4535
# April        4524
# October      4246
# September    4116
# March        3149
# February     2696
# December     2371
# November     2122
# January      1807
# dtype: int64

# %%
#visualization
sns.set(rc={'figure.figsize':(25,10)})
sns.countplot(cancel['arrival_date_month'], order=df['arrival_date_month'].value_counts().index, color='g')
plt.title(' highest number of cancellations')
plt.xlabel('Month')
plt.ylabel('Number of Cancellation')
# Out:
# Text(0, 0.5, 'Number of Cancellation')

# %% [markdown]
# August is the highest cancelation becausse of high reservation too
